# %%
import numpy as np
import pandas as pd

import os,sys
import glob

import feather

import re

import psycopg2
import sqlalchemy

#os.chdir("/gnshealthcare/shared/nli/dataframe/r36m/")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from bokeh.plotting import figure, output_notebook, show

# %%
from blaze import *
import datetime
# Out:
# /gnshealthcare/shared/yyang/anaconda3/lib/python3.6/site-packages/odo/backends/pandas.py:102: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))

# %%
from multiprocessing import Pool

# %%
#display all output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 160)
pd.set_option('max_colwidth',100)

import time

import itertools

# %% [markdown]
# # connect with SQLALchemy

# %%
import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker

# %%
#>>>>>>>> MAKE CHANGES HERE <<<<<<<<<<<<< 
DATABASE = "gns200496v1"
USER = "yyang"
PASSWORD = "Cignadata1"
HOST = "cigna-redshift.cgqqgon9pujb.us-east-1.redshift.amazonaws.com"
PORT = "5439"
SCHEMA = "rawdata"      #default is "public"

# %%
####### connection and session creation ############## 
connection_string = "postgresql+psycopg2://%s:%s@%s:%s/%s" % (USER,PASSWORD,HOST,str(PORT),DATABASE)

# %%
connection_string
# Out:
# 'postgresql+psycopg2://yyang:Cignadata1@cigna-redshift.cgqqgon9pujb.us-east-1.redshift.amazonaws.com:5439/gns200496v1'

# %%
engine = sa.create_engine(connection_string)
session = sessionmaker()
session.configure(bind=engine)
s = session()
SetPath = "SET search_path TO %s" % SCHEMA
s.execute(SetPath)
###### All Set Session created using provided schema  #######

# %% [markdown]
# Now we have SQLalchemy connection "s"

# %% [markdown]
# # Connect with psycopg2

# %%
con=psycopg2.connect(dbname= 'gns200496v1', host='cigna-redshift.cgqqgon9pujb.us-east-1.redshift.amazonaws.com',\
                     port= '5439', user= 'yyang', password='Cignadata1')

# %%
SCHEMA = "rawdata"      #default is "public"

# %%
cur = con.cursor()

# %%
SetPath = "SET search_path TO %s" % SCHEMA
cur.execute(SetPath)
con.commit()
###### All Set Session created using provided schema  #######

# %% [markdown]
# Now we have psycopg2 connection "con"

# %% [markdown]
# ***

# %% [markdown]
# # Read in R model output varnames

# %%
topvars_pd = feather.read_dataframe("/gnshealthcare/shared/yyang/data/ses_data/topvars_char.feather")

# %%
topvars_pd
# Out:
#                                                      .
# 0                          cig_v8626_a2yrincr_ip_indiv
# 1                          cig_v4000_consmr_promnc_ind
# 2             cig_v8637_occup_ip_indiv_16_mergedLevels
# 3                         cig_v8616_a2yrincr_1st_indiv
# 4                   cig_c06_001_pobtpp_res_in_ste_born
# 5             cig_v8637_occup_ip_indiv_15_mergedLevels
# 6                       cig_v7616_1_a2yrincr_1_indv_cd
# 7                         cig_c25_064_ohph_electricity
# 8                                  cig_v8655_lfestg_cd
# 9                                 cig_v8640_num_of_src
# 10                            cig_v8637_occup_ip_indiv
# 11            cig_v8637_occup_ip_indiv_20_mergedLevels
# 12            cig_v8637_occup_ip_indiv_14_mergedLevels
# 13            cig_v8637_occup_ip_indiv_11_mergedLevels
# 14                     cig_c06_002_pobtpp_res_oos_born
# 15                         cig_c04_001_atltpp_american
# 16                          cig_c03_001_hspogn_tpp_hsp
# 17                                   cig_c27_001_hi_pp
# 18                             cig_c04_030_atltpp_othr
# 19                             cig_c27_010_hi_pp_no_hi
# 20                          cig_c25_062_ohph_utlty_gas
# 21                          cig_c04_007_atltpp_english
# 22                    cig_c24_004_ocp_manufacturing_pp
# 23                        cig_v8617_a2yrincr_2nd_indiv
# 24                  cig_c03_006_hspogn_tltpp_othr_hspo
# 25                    cig_v8201_incm_estd_hh_highr_rng
# 26                           cig_c04_011_atltpp_german
# 27                           cig_c23_006_empd_fa16p_pp
# 28  cig_v8610_2_fng_1st_indiv_mid_init_20_mergedLevels
# 29                  cig_c27_003_hi_pp_emplr_provd_prvt
# 30                  cig_v8610_2_fng_1st_indiv_mid_init
# 31                      cig_c03_002_hspogn_tpp_non_hsp
# 32                            cig_c16_002_lah_pp_spnsh
# 33                             cig_c23_003_lf_fa16p_pp
# 34    cig_v8201_incm_estd_hh_highr_rng_16_mergedLevels
# 35                          cig_c01_018_hspo_a65p_tlpp
# 36                          cig_c08_019_wa16p_cmtm_mdn
# 37                               cig_c25_074_hup_3_brm
# 38  cig_v8610_2_fng_1st_indiv_mid_init_15_mergedLevels
# 39  cig_v8610_2_fng_1st_indiv_mid_init_16_mergedLevels
# 40                   cig_c08_002_wa16p_pp_wrk_out_cnty
# 41  cig_v8610_2_fng_1st_indiv_mid_init_12_mergedLevels
# 42  cig_v8610_2_fng_1st_indiv_mid_init_19_mergedLevels
# 43                             cig_c11_035_hhr_pct_hsp
# 44                          cig_c15_007_ea_pp_atand_bd
# 45                             cig_c23_002_lf_ma16p_pp
# 46                          cig_v2778_brnd_nm_med_ppns
# 47                      cig_c08_004_wa16p_pp_drv_alone
# 48                             cig_c08_029_hhvap_2_veh
# 49                     cig_v8671_incm_estd_hh_narw_rng
# 50  cig_v8610_2_fng_1st_indiv_mid_init_13_mergedLevels
# 51  cig_v8610_2_fng_1st_indiv_mid_init_11_mergedLevels
# 52                            cig_c11_036_hhr_pct_nhsp
# 53                                 cig_c19_043_hhip_ss
# 54                   cig_c08_020_wa16p_pp_cmtm_1_29_mn
# 55                    cig_c08_025_wa16p_pp_cmtm_60p_mn
# 56                       cig_c11_024_hhr_pct_age_65_74
# 57    cig_v3102_cntry_of_orgn_high_dtl_23_mergedLevels
# 58                       cig_c06_004_pobtpp_forgn_born
# 59                        cig_c05_001_ctltpp_ntv_citzn
# 60                            cig_c23_004_empd_a16p_pp
# 61      cig_v8671_incm_estd_hh_narw_rng_8_mergedLevels
# 62    cig_v8201_incm_estd_hh_highr_rng_15_mergedLevels
# 63                    cig_c08_001_wa16p_pp_wrk_in_cnty
# 64                            cig_c25_096_oohu_avg_val
# 65                          cig_c25_118_soohu_pct_mrtg
# 66                  cig_v8642_hmv_estd_15_mergedLevels
# 67                          cig_c04_015_atltpp_italian
# 68                     cig_c16_001_lah_pp_english_only
# 69                        cig_c24_033_ocp_self_empd_pp
# 70    cig_v3102_cntry_of_orgn_high_dtl_16_mergedLevels
# 71     cig_v8671_incm_estd_hh_narw_rng_12_mergedLevels
# 72                       cig_v8644_home_purchs_yr_yyyy
# 73                  cig_c24_010_ocp_fins_re_rntl_lsgpp
# 74                   cig_c24_032_ocp_pfp_nself_empd_pp
# 75                           cig_c23_005_empd_ma16p_pp
# 76                             cig_v3589_mcu_primtm_tv

# %% [markdown]
# ## process varnames as some of them has extra postfix

# %% [markdown]
# Like "_mergedLevels" and "_isNA_factor" were generated during feature QC/engineering stage. After removing them, calculate the uniq(list)

# %%
topvars_pd.iloc[:,0].apply(lambda x : re.sub('(_\d+_mergedLevels|_isNA_factor)$', '', x))
# Out:
# 0            cig_v8626_a2yrincr_ip_indiv
# 1            cig_v4000_consmr_promnc_ind
# 2               cig_v8637_occup_ip_indiv
# 3           cig_v8616_a2yrincr_1st_indiv
# 4     cig_c06_001_pobtpp_res_in_ste_born
# 5               cig_v8637_occup_ip_indiv
# 6         cig_v7616_1_a2yrincr_1_indv_cd
# 7           cig_c25_064_ohph_electricity
# 8                    cig_v8655_lfestg_cd
# 9                   cig_v8640_num_of_src
# 10              cig_v8637_occup_ip_indiv
# 11              cig_v8637_occup_ip_indiv
# 12              cig_v8637_occup_ip_indiv
# 13              cig_v8637_occup_ip_indiv
# 14       cig_c06_002_pobtpp_res_oos_born
# 15           cig_c04_001_atltpp_american
# 16            cig_c03_001_hspogn_tpp_hsp
# 17                     cig_c27_001_hi_pp
# 18               cig_c04_030_atltpp_othr
# 19               cig_c27_010_hi_pp_no_hi
# 20            cig_c25_062_ohph_utlty_gas
# 21            cig_c04_007_atltpp_english
# 22      cig_c24_004_ocp_manufacturing_pp
# 23          cig_v8617_a2yrincr_2nd_indiv
# 24    cig_c03_006_hspogn_tltpp_othr_hspo
# 25      cig_v8201_incm_estd_hh_highr_rng
# 26             cig_c04_011_atltpp_german
# 27             cig_c23_006_empd_fa16p_pp
# 28    cig_v8610_2_fng_1st_indiv_mid_init
# 29    cig_c27_003_hi_pp_emplr_provd_prvt
# 30    cig_v8610_2_fng_1st_indiv_mid_init
# 31        cig_c03_002_hspogn_tpp_non_hsp
# 32              cig_c16_002_lah_pp_spnsh
# 33               cig_c23_003_lf_fa16p_pp
# 34      cig_v8201_incm_estd_hh_highr_rng
# 35            cig_c01_018_hspo_a65p_tlpp
# 36            cig_c08_019_wa16p_cmtm_mdn
# 37                 cig_c25_074_hup_3_brm
# 38    cig_v8610_2_fng_1st_indiv_mid_init
# 39    cig_v8610_2_fng_1st_indiv_mid_init
# 40     cig_c08_002_wa16p_pp_wrk_out_cnty
# 41    cig_v8610_2_fng_1st_indiv_mid_init
# 42    cig_v8610_2_fng_1st_indiv_mid_init
# 43               cig_c11_035_hhr_pct_hsp
# 44            cig_c15_007_ea_pp_atand_bd
# 45               cig_c23_002_lf_ma16p_pp
# 46            cig_v2778_brnd_nm_med_ppns
# 47        cig_c08_004_wa16p_pp_drv_alone
# 48               cig_c08_029_hhvap_2_veh
# 49       cig_v8671_incm_estd_hh_narw_rng
# 50    cig_v8610_2_fng_1st_indiv_mid_init
# 51    cig_v8610_2_fng_1st_indiv_mid_init
# 52              cig_c11_036_hhr_pct_nhsp
# 53                   cig_c19_043_hhip_ss
# 54     cig_c08_020_wa16p_pp_cmtm_1_29_mn
# 55      cig_c08_025_wa16p_pp_cmtm_60p_mn
# 56         cig_c11_024_hhr_pct_age_65_74
# 57      cig_v3102_cntry_of_orgn_high_dtl
# 58         cig_c06_004_pobtpp_forgn_born
# 59          cig_c05_001_ctltpp_ntv_citzn
# 60              cig_c23_004_empd_a16p_pp
# 61       cig_v8671_incm_estd_hh_narw_rng
# 62      cig_v8201_incm_estd_hh_highr_rng
# 63      cig_c08_001_wa16p_pp_wrk_in_cnty
# 64              cig_c25_096_oohu_avg_val
# 65            cig_c25_118_soohu_pct_mrtg
# 66                    cig_v8642_hmv_estd
# 67            cig_c04_015_atltpp_italian
# 68       cig_c16_001_lah_pp_english_only
# 69          cig_c24_033_ocp_self_empd_pp
# 70      cig_v3102_cntry_of_orgn_high_dtl
# 71       cig_v8671_incm_estd_hh_narw_rng
# 72         cig_v8644_home_purchs_yr_yyyy
# 73    cig_c24_010_ocp_fins_re_rntl_lsgpp
# 74     cig_c24_032_ocp_pfp_nself_empd_pp
# 75             cig_c23_005_empd_ma16p_pp
# 76               cig_v3589_mcu_primtm_tv
# Name: ., dtype: object

# %%
topvars_pd.iloc[:,0] = topvars_pd.iloc[:,0].apply(lambda x : re.sub('(_\d+_mergedLevels|_isNA_factor)$', '', x))

# %% [markdown]
# ## split by cig_v or cig_c to two lists, since census and lifestyle tables are two tables in rawdata schema (wide format, query fast)

# %%
census_topvars_lt = [re.sub('^cig_', '' , x) for x in topvars_pd.iloc[:,0] if re.search("cig_c", x)]

# %%
lifestyle_topvars_lt = [re.sub('^cig_', '' , x)  for x in topvars_pd.iloc[:,0] if re.search("cig_v", x)]

# %%
def count_duplicates(seq): 

    '''takes as argument a sequence and
    returns the number of duplicate elements'''

    return len(seq) - len(set(seq))

res = count_duplicates([-1,2,4,2,0,4,4])
print(res)  # -> 3
# Out:
# 3

# %%
count_duplicates(census_topvars_lt)
# Out:
# 0

# %%
count_duplicates(lifestyle_topvars_lt)
# Out:
# 17

# %% [markdown]
# ### dedupe the list of SES variables after removing prefix and postfix

# %%
census_topvars_lt = list(set(census_topvars_lt))

lifestyle_topvars_lt = list(set(lifestyle_topvars_lt))

# %%
len(census_topvars_lt)
len(lifestyle_topvars_lt)
# Out:
# 44
# 16

# %%
len(census_topvars_lt) + len(lifestyle_topvars_lt)
# Out:
# 60

# %%
len(topvars_pd)
# Out:
# 77

# %%
# #: check if splits summed to all.
# if (len(census_topvars_lt) + len(lifestyle_topvars_lt) != len(topvars_pd)):
#     raise ValueError("sum of two parts not equal to expected all")

# %% [markdown]
# # Query start

# %% [markdown]
# ## create new table for storing mapping member id from csv file

# %% [markdown]
# #####  skip cause we already have analyst.oncology_m4_8_6 table in Redshift.

# %%
# #: run only once

# #create the table but first drop if it already exists
# command = '''
# DROP TABLE IF EXISTS analyst.origid_m31pop_100k_2;
# CREATE TABLE analyst.origid_m31pop_100k_2
# (
#     indiv_enterprise_id VARCHAR(40)
# ) 
# --DISTKEY(indiv_enterprise_id) SORTKEY(indiv_enterprise_id);
# '''
# cur.execute(command)
# con.commit()

# #create the table but first drop if it already exists
# sel = '''
# select count(*) from analyst.origid_m31pop_100k_2
# '''
# cur.execute(sel)
# cur.fetchall()


# sel = '''
# select count(*) from analyst.csm_case_src_cd
# '''
# cur.execute(sel)
# cur.fetchall()


# sel = '''
# select top 10 * from analyst.csm_case_src_cd
# '''
# cur.execute(sel)
# cur.fetchall()

# #create the table but first drop if it already exists
# sel = '''
# select top 10 * from analyst.origid_m31pop_100k_2
# '''
# cur.execute(sel)
# cur.fetchall()

# [x for x in m31pop_100k.origId[:10]]

# con.commit()

# #args = [(1,2), (3,4), (5,6)]
# start = 0
# while (start < len(m31pop_100k)):
#     args_str = b",".join(cur.mogrify("(%s)", (x, )) for x in m31pop_100k.origId[start: ( start + int(1e3) )])
#     cur.execute("INSERT INTO analyst.origid_m31pop_100k_2 VALUES " + args_str.decode())
#     start += int(1e3)
#     print(start)
    

# con.commit()

# #create the table but first drop if it already exists
# sel = '''
# select top 10 * from analyst.origid_m31pop_100k_2
# '''
# cur.execute(sel)
# cur.fetchall()

# #create the table but first drop if it already exists
# sel = '''
# select count(*) from analyst.origid_m31pop_100k_2
# '''
# cur.execute(sel)
# cur.fetchall()

# #create the table but first drop if it already exists
# sel = '''
# select count(distinct indiv_enterprise_id) from analyst.origid_m31pop_100k_2
# '''
# cur.execute(sel)
# cur.fetchall()

# %% [markdown]
# ## SQL extract  census and lifestyle variables respectively

# %%
#: test
#: census first, "c" initial words.
# join table to 100k members, instead of using python obj

sel = '''
select top 10 * from rawdata.census as c
right join analyst.oncology_m4_8_6 as m on c.indiv_enterprise_id = m.indiv_enterprise_id;
'''

census_tables = pd.read_sql(sel, con)
census_tables.head(10)
# Out:
#   ac_nielsen_cnty_sz_cd   assmt_dt              assmt_id brnch_cd  \
# 0                     B  30-MAY-18  20180503080056832194      ACT
# 1                     A  30-MAY-18  20180503080036341964    NONNC
# 2                     B  30-MAY-18  20180503080016250180   73873A
# 3                     A  30-MAY-18  20180503080071025944      MII
# 4                     B  30-MAY-18  20180503080081305995     BCCA
# 5                     A  30-MAY-18  20180503080096961067      798
# 6                     B  30-MAY-18  20180503080031633264     BCCA
# 7                     A  30-MAY-18  20180503080096966850     601H
# 8                     A  08-NOV-17  20171103080023141770      EDM
# 9                     A  30-MAY-18  20180503080051013669    ARFNS
#
#                                             brnch_nm c00_000_miacs_mtch_cd  \
# 0                               ALL ACTIVE EMPLOYEES                     E
# 1                       NON NORTH CAROLINA EMPLOYEES                     E
# 2                           ORLANDO CONTAINER ACTIVE                     E
# 3                           500 MII - SERVICE ACTIVE                     E
# 4                                         BCC ACTIVE                     E
# 5                                     CORPORATE - NY                     E
# 6                                         BCC ACTIVE                     E
# 7                                        STORES - NY                     E
# 8                            EPSILON DATA MANAGEMENT                     E
# 9  ACTIVE CONSUMER & COMMUNITY BANKING BUSINESS NSMK                     E
#
#   c00_001_ttl_ppln_num c00_002_hh_ttl_ppln_num c00_003_grp_qtrs_ttl_ppln_num  \
# 0               004613                  004556                        000057
# 1               001308                  001308                        000000
# 2               007196                  007195                        000001
# 3               001032                  001032                        000000
# 4               002274                  002274                        000000
# 5               005471                  005442                        000029
# 6               000628                  000628                        000000
# 7               001659                  001659                        000000
# 8               001208                  001208                        000000
# 9               002285                  002285                        000000
#
#   c00_004_tn_hh c00_005_tn_fam_hh c00_006_tn_non_fam_hh c00_007_tn_hu  \
# 0        001609            001068                000541        001868
# 1        000522            000370                000152        000611
# 2        002459            001622                000837        002782
# 3        000441            000331                000110        000460
# 4        001083            000624                000459        001360
# 5        001483            001378                000105        001524
# 6        000242            000146                000096        000282
# 7        000680            000392                000288        000748
# 8        000509            000404                000105        000530
# 9        000642            000551                000091        000642
#
#   c00_008_tn_vcnt_hu c01_001_gendr_male_tpp c01_002_gendr_fem_tpp  \
# 0             000259                     51                    49
# 1             000089                     44                    56
# 2             000323                     54                    46
# 3             000019                     49                    51
# 4             000277                     39                    61
# 5             000041                     51                    49
# 6             000040                     52                    48
# 7             000068                     51                    49
# 8             000021                     48                    52
# 9             000000                     47                    53
#
#   c01_003_tp_age_avg c01_004_tp_age_mdn c01_005_tp_male_age_mdn  \
# 0               36.6               35.2                    32.5
# 1               38.9               42.7                    43.1
# 2               42.4               42.7                    42.2
# 3               40.1               34.5                    33.5
# 4               50.4               54.2                    57.9
# 5               33.4               38.0                    29.2
# 6               41.7               40.8                    40.7
# 7               34.5               37.7                    38.6
# 8               48.3               51.1                    50.2
# 9               33.4               36.6                    38.6
#
#   c01_006_tp_fem_age_mdn c01_007_alt18_tpp c01_008_age_18_64_tpp  \
# 0                   38.6                28                    60
# 1                   42.2                30                    52
# 2                   44.8                18                    64
# 3                   38.0                20                    64
# 4                   50.7                14                    50
# 5                   39.1                36                    57
# 6                   44.3                25                    61
# 7                   28.4                28                    61
# 8                   53.2                20                    52
# 9                   34.7                35                    58
#
#   c01_009_a65p_tpp c01_010_whto_alt18_tlpp c01_011_whto_age_18_64_tlpp  \
# 0               12                      16                          64
# 1               18                      24                          64
# 2               18                      19                          62
# 3               16                      19                          63
# 4               36                      10                          52
# 5               07                      29                          60
# 6               14                      07                          76
# 7               11                      21                          72
# 8               28                      18                          61
# 9               07                      36                          59
#
#   c01_012_whto_a65p_tlpp c01_013_blko_alt18_tlpp c01_014_blko_age_18_64_tlpp  \
# 0                     20                      32                          59
# 1                     12                      00                          76
# 2                     19                      16                          79
# 3                     18                      23                          77
# 4                     38                      24                          65
# 5                     11                      43                          57
# 6                     17                      22                          57
# 7                     07                      22                          50
# 8                     21                      00                          99
# 9                     05                      22                          68
#
#   c01_015_blko_a65p_tlpp c01_016_hspo_alt18_tlpp c01_017_hspo_age_18_64_tlpp  \
# 0                     09                      28                          63
# 1                     24                      21                          62
# 2                     05                      21                          65
# 3                     00                      51                          49
# 4                     11                      20                          57
# 5                     00                      31                          62
# 6                     21                      09                          85
# 7                     28                      27                          65
# 8                     00                      25                          66
# 9                     10                      46                          54
#
#   c01_018_hspo_a65p_tlpp c01_019_hhlt18_tlpp_alt3 c01_020_hhlt18_tlpp_age_3_4  \
# 0                     09                       12                          13
# 1                     17                       08                          10
# 2                     14                       20                          06
# 3                     00                       13                          10
# 4                     23                       25                          13
# 5                     07                       07                          07
# 6                     06                       21                          14
# 7                     08                       21                          15
# 8                     09                       12                          09
# 9                     00                       06                          12
#
#   c01_021_hhlt18_tlpp_a5 c01_022_hhlt18_tlpp_age_3_5 c01_023_hhlt18_tlpp_a6_8  \
# 0                     04                          17                       09
# 1                     04                          14                       18
# 2                     06                          12                       09
# 3                     05                          15                       11
# 4                     00                          13                       34
# 5                     05                          12                       21
# 6                     02                          16                       20
# 7                     05                          20                       08
# 8                     05                          14                       11
# 9                     04                          16                       17
#
#   c01_024_hhlt18_tlpp_age_9_11 c01_025_hhlt18_tlpp_age_6_11  \
# 0                           13                           22
# 1                           18                           36
# 2                           22                           31
# 3                           19                           30
# 4                           06                           40
# 5                           17                           38
# 6                           07                           27
# 7                           18                           26
# 8                           10                           21
# 9                           26                           43
#
#   c01_026_hhlt18_tlpp_age_12_14 c01_027_hhlt18_tlpp_age_15_17  \
# 0                            19                            30
# 1                            24                            18
# 2                            23                            14
# 3                            18                            24
# 4                            08                            14
# 5                            24                            19
# 6                            25                            11
# 7                            13                            20
# 8                            25                            28
# 9                            17                            18
#
#   c01_028_ppln_a18p_avg_age c01_029_ppln_a18p_mdn_age  \
# 0                      46.7                      46.6
# 1                      51.3                      49.4
# 2                      49.1                      47.8
# 3                      47.9                      45.4
# 4                      57.2                      59.1
# 5                      45.8                      45.6
# 6                      53.6                      53.9
# 7                      44.4                      40.9
# 8                      57.5                      56.5
# 9                      46.2                      45.9
#
#   c01_030_ppln_a25p_avg_age c01_031_ppln_a25p_mdn_age c01_032_a18p_pp_18_24  \
# 0                      50.9                      50.2                    14
# 1                      52.8                      50.7                    05
# 2                      50.8                      48.9                    06
# 3                      49.3                      49.3                    05
# 4                      59.6                      61.2                    06
# 5                      49.8                      47.8                    14
# 6                      53.6                      53.9                    00
# 7                      45.9                      42.3                    06
# 8                      58.2                      57.2                    02
# 9                      48.9                      47.7                    10
#
#   c01_033_a18p_pp_25_34 c01_034_a18p_pp_35_44 c01_035_a18p_pp_45_54  \
# 0                    16                    16                    18
# 1                    10                    29                    19
# 2                    16                    20                    22
# 3                    35                    10                    07
# 4                    08                    13                    17
# 5                    06                    28                    30
# 6                    13                    28                    11
# 7                    22                    30                    15
# 8                    09                    12                    25
# 9                    07                    31                    25
#
#   c01_036_a18p_pp_55_64 c01_037_a18p_pp_65_74 c01_038_a18p_pp_75  \
# 0                    19                    12                 05
# 1                    12                    19                 06
# 2                    14                    16                 06
# 3                    23                    14                 06
# 4                    14                    24                 18
# 5                    11                    07                 04
# 6                    29                    10                 09
# 7                    11                    12                 04
# 8                    17                    21                 14
# 9                    17                    09                 01
#
#   c02_001_rc_whto_tpp c02_002_rc_blko_tpp c02_003_rc_aiano_tpp  \
# 0                  27                  63                   00
# 1                  94                  00                   03
# 2                  82                  13                   01
# 3                  93                  00                   01
# 4                  92                  01                   00
# 5                  96                  01                   00
# 6                  17                  83                   00
# 7                  35                  05                   00
# 8                  95                  01                   00
# 9                  79                  03                   00
#
#   c02_004_rc_asiano_tpp c02_005_rc_nhopio_tpp c02_006_rc_oro_tpp  \
# 0                    01                    00                 08
# 1                    03                    00                 00
# 2                    01                    00                 01
# 3                    00                    00                 00
# 4                    04                    00                 02
# 5                    02                    00                 01
# 6                    00                    00                 00
# 7                    50                    00                 06
# 8                    02                    00                 02
# 9                    16                    00                 00
#
#   c02_007_rc_2p_rcs_tpp c02_008_asian_stlpp_asian_ind  \
# 0                    01                            36
# 1                    00                            94
# 2                    02                            51
# 3                    06                            00
# 4                    01                            12
# 5                    00                            41
# 6                    00                            86
# 7                    04                            17
# 8                    00                            00
# 9                    02                            46
#
#   c02_009_asian_stlpp_japanese c02_010_asian_stlpp_chinese  \
# 0                           00                          00
# 1                           06                          00
# 2                           00                          03
# 3                           53                          47
# 4                           00                          05
# 5                           00                          00
# 6                           00                          00
# 7                           00                          37
# 8                           13                          47
# 9                           00                          33
#
#   c02_011_asian_stlpp_filipino c02_012_asian_stlpp_korean  \
# 0                           00                         00
# 1                           00                         00
# 2                           26                         00
# 3                           00                         00
# 4                           76                         07
# 5                           00                         00
# 6                           14                         00
# 7                           09                         02
# 8                           00                         30
# 9                           06                         09
#
#   c02_013_asian_stlpp_vietnamese c02_014_asian_stlpp_othr_asian  \
# 0                             64                             00
# 1                             00                             00
# 2                             00                             20
# 3                             00                             00
# 4                             00                             00
# 5                             00                             59
# 6                             00                             00
# 7                             02                             33
# 8                             00                             10
# 9                             05                             01
#
#   c02_015_nhopi_stlpp_ntv_hawaii c02_016_nhopi_stlpp_guan_cham  \
# 0                             00                            00
# 1                             00                            00
# 2                             00                            00
# 3                             00                            00
# 4                             00                            00
# 5                             00                            00
# 6                             00                            00
# 7                             00                            00
# 8                             99                            00
# 9                             00                            00
#
#   c02_017_nhopi_stlpp_samoan c02_018_nhopi_stlpp_opi c03_001_hspogn_tpp_hsp  \
# 0                         00                      00                     12
# 1                         00                      00                     02
# 2                         00                      00                     18
# 3                         00                      00                     04
# 4                         00                      00                     07
# 5                         00                      00                     13
# 6                         00                      00                     00
# 7                         00                      00                     37
# 8                         00                      00                     06
# 9                         00                      00                     07
#
#   c03_002_hspogn_tpp_non_hsp c03_003_hspogn_tltpp_mexican  \
# 0                         88                           02
# 1                         98                           01
# 2                         82                           02
# 3                         96                           02
# 4                         93                           00
# 5                         87                           02
# 6                         99                           01
# 7                         63                           10
# 8                         94                           07
# 9                         93                           07
#
#   c03_004_hspogn_tltpp_purto_rcn c03_005_hspogn_tltpp_cuban  \
# 0                             08                         00
# 1                             00                         00
# 2                             09                         02
# 3                             01                         00
# 4                             13                         00
# 5                             05                         01
# 6                             16                         02
# 7                             03                         04
# 8                             01                         00
# 9                             00                         00
#
#   c03_006_hspogn_tltpp_othr_hspo c03_007_rnhsp_whto_tpp  \
# 0                             02                     21
# 1                             00                     92
# 2                             06                     66
# 3                             00                     92
# 4                             05                     85
# 5                             03                     83
# 6                             05                     17
# 7                             28                     08
# 8                             05                     92
# 9                             02                     73
#
#   c03_008_rnhsp_blko_tpp c03_009_rnhsp_aiano_tpp c03_010_rnhsp_asiano_tpp  \
# 0                     63                      00                       02
# 1                     00                      02                       04
# 2                     13                      00                       01
# 3                     00                      01                       00
# 4                     01                      00                       04
# 5                     01                      00                       02
# 6                     83                      00                       00
# 7                     04                      00                       50
# 8                     01                      00                       01
# 9                     03                      00                       16
#
#   c03_011_rnhsp_nhopio_tpp c03_012_rnhsp_oro_tpp c03_013_rnhsp_ovr_2_rcs_tpp  \
# 0                       00                    02                          00
# 1                       00                    00                          00
# 2                       00                    00                          02
# 3                       00                    00                          03
# 4                       00                    02                          01
# 5                       00                    01                          00
# 6                       00                    00                          00
# 7                       00                    00                          01
# 8                       00                    00                          00
# 9                       00                    00                          01
#
#   c04_001_atltpp_american c04_002_atltpp_arab c04_003_atltpp_british  \
# 0                      07                  00                     00
# 1                      06                  01                     01
# 2                      10                  01                     01
# 3                      07                  02                     01
# 4                      06                  00                     02
# 5                      04                  00                     00
# 6                      03                  00                     00
# 7                      04                  01                     00
# 8                      04                  00                     00
# 9                      04                  03                     01
#
#   c04_004_atltpp_czech c04_005_atltpp_danish c04_006_atltpp_dutch  \
# 0                   00                    00                   00
# 1                   00                    00                   02
# 2                   00                    00                   00
# 3                   01                    00                   01
# 4                   01                    00                   00
# 5                   01                    00                   01
# 6                   00                    00                   00
# 7                   00                    00                   00
# 8                   00                    01                   01
# 9                   00                    00                   03
#
#   c04_007_atltpp_english c04_008_atltpp_european c04_009_atltpp_french  \
# 0                     03                      00                    02
# 1                     12                      03                    07
# 2                     09                      01                    03
# 3                     10                      02                    08
# 4                     10                      08                    04
# 5                     06                      00                    04
# 6                     03                      00                    00
# 7                     00                      00                    00
# 8                     20                      08                    03
# 9                     08                      00                    01
#
#   c04_010_atltpp_french_canadian c04_011_atltpp_german c04_012_atltpp_greek  \
# 0                             00                    04                   00
# 1                             04                    23                   00
# 2                             02                    13                   01
# 3                             05                    23                   02
# 4                             01                    20                   01
# 5                             00                    19                   01
# 6                             01                    02                   00
# 7                             00                    01                   00
# 8                             00                    25                   00
# 9                             00                    25                   01
#
#   c04_013_atltpp_hungarian c04_014_atltpp_irish c04_015_atltpp_italian  \
# 0                       00                   05                     02
# 1                       01                   15                     06
# 2                       00                   10                     04
# 3                       01                   13                     06
# 4                       04                   10                     06
# 5                       01                   23                     37
# 6                       00                   02                     01
# 7                       00                   02                     00
# 8                       02                   11                     06
# 9                       01                   09                     07
#
#   c11_028_hhr_rc_whto_tpp c11_027_hhr_pct_a65p c11_026_hhr_pct_a85p  \
# 0                      28                   14                   00
# 1                      98                   29                   04
# 2                      80                   32                   01
# 3                      99                   21                   02
# 4                      96                   48                   05
# 5                      97                   09                   00
# 6                      20                   30                   07
# 7                      31                   17                   00
# 8                      93                   42                   09
# 9                      79                   09                   00
#
#   c11_025_hhr_pct_age_75_84 c11_024_hhr_pct_age_65_74  \
# 0                        05                        09
# 1                        03                        22
# 2                        08                        23
# 3                        04                        15
# 4                        12                        31
# 5                        06                        03
# 6                        06                        17
# 7                        07                        10
# 8                        13                        20
# 9                        00                        09
#
#   c11_023_hhr_pct_age_55_64 c11_022_hhr_pct_age_45_54  \
# 0                        27                        22
# 1                        12                        21
# 2                        19                        22
# 3                        25                        08
# 4                        14                        14
# 5                        17                        40
# 6                        25                        05
# 7                        08                        23
# 8                        20                        20
# 9                        24                        31
#
#   c11_021_hhr_pct_age_35_44 c11_020_hhr_pct_age_25_34  \
# 0                        17                        16
# 1                        30                        08
# 2                        18                        09
# 3                        11                        35
# 4                        16                        08
# 5                        30                        04
# 6                        21                        19
# 7                        28                        24
# 8                        14                        04
# 9                        29                        07
#
#   c11_019_hhr_pct_age_15_24 c11_018_eld_a65p_livng_aln_hhp  \
# 0                        04                             04
# 1                        00                             13
# 2                        00                             09
# 3                        00                             06
# 4                        00                             26
# 5                        00                             04
# 6                        00                             13
# 7                        00                             12
# 8                        00                             13
# 9                        00                             00
#
#   c11_017_eld_a65p_hhp c11_016_rchd_sfhhr_hhp c11_015_rchd_smhhr_hhp  \
# 0                   22                     19                     01
# 1                   31                     08                     02
# 2                   39                     01                     05
# 3                   25                     11                     02
# 4                   49                     09                     00
# 5                   19                     03                     00
# 6                   30                     13                     00
# 7                   23                     00                     06
# 8                   43                     00                     02
# 9                   15                     00                     02
#
#   c11_014_rchd_shhr_0_chrn_hhp c11_013_rchd_shhr_hhp  \
# 0                           09                    20
# 1                           08                    10
# 2                           08                    06
# 3                           02                    13
# 4                           09                    09
# 5                           08                    03
# 6                           25                    13
# 7                           06                    06
# 8                           06                    02
# 9                           01                    02
#
#   c11_012_rchd_mrdcpl_0_chrn_hhp c11_011_rchd_mrdcpl_hhp c11_010_rchd_hhp  \
# 0                             18                      19               39
# 1                             20                      33               43
# 2                             33                      19               25
# 3                             45                      14               27
# 4                             32                      08               17
# 5                             22                      60               63
# 6                             07                      15               28
# 7                             17                      29               35
# 8                             51                      21               23
# 9                             31                      52               54
#
#   c11_009_ochd_sfhhr_hhp c11_008_ochd_smhhr_hhp c11_007_ochd_shhr_hhp  \
# 0                     17                     01                    18
# 1                     04                     02                    06
# 2                     01                     05                    06
# 3                     11                     02                    13
# 4                     09                     00                    09
# 5                     03                     00                    03
# 6                     13                     00                    13
# 7                     00                     06                    06
# 8                     00                     02                    02
# 9                     00                     01                    01
#
#   c11_006_ochd_mrdcpl_hhp c11_005_ochd_hhp c11_004_0_chrn_per_hhp  \
# 0                      14               32                     61
# 1                      33               39                     57
# 2                      18               24                     70
# 3                      14               27                     73
# 4                      08               17                     83
# 5                      59               62                     37
# 6                      06               19                     72
# 7                      29               35                     65
# 8                      19               21                     77
# 9                      51               52                     46
#
#   c11_003_chrn_per_hhp c11_002_hhr_gendr_fem_tl_pct  \
# 0                   39                           50
# 1                   43                           58
# 2                   30                           38
# 3                   27                           52
# 4                   17                           61
# 5                   63                           44
# 6                   28                           50
# 7                   35                           30
# 8                   23                           43
# 9                   54                           36
#
#   c11_001_hhr_gendr_male_tl_pct c10_002_gprnt_a30p_rfgc_hhp  \
# 0                            50                          04
# 1                            42                          01
# 2                            62                          00
# 3                            48                          00
# 4                            39                          00
# 5                            56                          00
# 6                            50                          02
# 7                            70                          02
# 8                            57                          02
# 9                            64                          00
#
#   c10_001_gprnt_a30p_rfgc_pp c09_004_not_fam_hh_livng_tltpp  \
# 0                         04                             14
# 1                         01                             12
# 2                         00                             19
# 3                         00                             11
# 4                         00                             22
# 5                         00                             02
# 6                         03                             20
# 7                         01                             18
# 8                         01                             09
# 9                         00                             06
#
#   c09_003_fam_hh_livng_tltpp c09_002_grp_livng_tltpp c09_001_hh_livng_tltpp  \
# 0                         86                      01                     99
# 1                         88                      00                     99
# 2                         81                      00                     99
# 3                         89                      00                     99
# 4                         78                      00                     99
# 5                         98                      01                     99
# 6                         80                      00                     99
# 7                         82                      00                     99
# 8                         91                      00                     99
# 9                         94                      00                     99
#
#   c08_038_ro_hh_vhav_mdn c08_037_ro_hh_vhav_avg c08_036_oo_hh_vhav_mdn  \
# 0                    1.0                    1.0                    2.0
# 1                    1.0                    0.0                    2.0
# 2                    1.0                    1.1                    2.0
# 3                    2.0                    1.9                    2.0
# 4                    1.0                    1.2                    2.0
# 5                    2.0                    0.0                    2.0
# 6                    1.0                    0.8                    2.0
# 7                    0.0                    0.2                    1.0
# 8                    0.0                    0.0                    2.0
# 9                    2.0                    2.2                    2.0
#
#   c08_035_oo_hh_vhav_avg c08_034_hhr_a65p_1p_vhav_pct  \
# 0                    2.0                           13
# 1                    0.0                           27
# 2                    2.0                           29
# 3                    1.7                           21
# 4                    1.6                           45
# 5                    0.0                           07
# 6                    1.2                           15
# 7                    1.0                           09
# 8                    0.0                           33
# 9                    2.5                           09
#
#   c08_033_hhr_a35_64_1p_vhav_pct c08_032_hhr_a15_34_1p_vhav_pct  \
# 0                             58                             17
# 1                             61                             08
# 2                             55                             08
# 3                             43                             33
# 4                             43                             09
# 5                             88                             04
# 6                             27                             19
# 7                             22                             03
# 8                             55                             03
# 9                             84                             07
#
#   c08_031_hhvap_3p_veh c08_030_hhvap_2p_veh c08_029_hhvap_2_veh  \
# 0                   13                   36                  23
# 1                   20                   65                  45
# 2                   14                   63                  49
# 3                   09                   61                  52
# 4                   07                   42                  35
# 5                   39                   89                  50
# 6                   00                   38                  38
# 7                   00                   05                  05
# 8                   24                   74                  50
# 9                   35                   94                  59
#
#   c08_028_hhvap_1p_veh c08_027_hhvap_1_veh c08_026_hhvap_0_veh  \
# 0                   88                  52                  12
# 1                   96                  31                  04
# 2                   92                  29                  08
# 3                   97                  36                  03
# 4                   97                  55                  03
# 5                   99                  10                  01
# 6                   61                  23                  39
# 7                   34                  29                  66
# 8                   91                  17                  09
# 9                   99                  06                  00
#
#   c08_025_wa16p_pp_cmtm_60p_mn c08_024_wa16p_pp_cmtm_15_59_mn  \
# 0                           10                             74
# 1                           08                             85
# 2                           13                             61
# 3                           03                             81
# 4                           13                             53
# 5                           14                             77
# 6                           00                             78
# 7                           14                             84
# 8                           11                             78
# 9                           05                             77
#
#   c08_023_wa16p_pp_cmtm_90p_mn c08_022_wa16p_pp_cmtm_60_89_mn  \
# 0                           04                             06
# 1                           02                             06
# 2                           02                             11
# 3                           00                             03
# 4                           07                             06
# 5                           03                             11
# 6                           00                             00
# 7                           00                             14
# 8                           03                             08
# 9                           01                             04
#
#   c08_021_wa16p_pp_cmtm_30_59_mn c08_020_wa16p_pp_cmtm_1_29_mn  \
# 0                             38                            52
# 1                             45                            47
# 2                             37                            50
# 3                             41                            56
# 4                             20                            67
# 5                             44                            42
# 6                             28                            72
# 7                             72                            14
# 8                             30                            59
# 9                             28                            67
#
#   c08_019_wa16p_cmtm_mdn c08_018_wa16p_cmtm_avg c08_017_wa16p_pp_wrk_frm_home  \
# 0                    028                    031                            03
# 1                    031                    000                            01
# 2                    029                    031                            00
# 3                    025                    000                            00
# 4                    019                    000                            12
# 5                    033                    033                            03
# 6                    022                    000                            00
# 7                    037                    000                            00
# 8                    026                    000                            05
# 9                    022                    024                            02
#
#   c08_016_wa16p_pp_othr_trnsprt c08_015_wa16p_pp_walk  \
# 0                            01                    01
# 1                            00                    00
# 2                            00                    00
# 3                            00                    00
# 4                            02                    01
# 5                            00                    00
# 6                            00                    00
# 7                            00                    01
# 8                            00                    00
# 9                            00                    01
#
#   c08_014_wa16p_pp_rid_bicyc c08_013_wa16p_pp_rid_motrcyc  \
# 0                         00                           02
# 1                         00                           00
# 2                         00                           00
# 3                         02                           00
# 4                         00                           00
# 5                         00                           00
# 6                         10                           00
# 7                         00                           00
# 8                         00                           00
# 9                         01                           00
#
#   c08_012_wa16p_pp_take_taxi c08_011_wa16p_pp_ptrn_ferry  \
# 0                         00                          00
# 1                         00                          00
# 2                         00                          00
# 3                         00                          00
# 4                         00                          00
# 5                         00                          00
# 6                         00                          00
# 7                         00                          00
# 8                         00                          00
# 9                         00                          00
#
#   c08_010_wa16p_pp_ptrn_trn c08_009_wa16p_pp_ptrn_subway  \
# 0                        00                           00
# 1                        00                           00
# 2                        00                           00
# 3                        00                           00
# 4                        00                           00
# 5                        00                           00
# 6                        00                           00
# 7                        03                           53
# 8                        00                           00
# 9                        00                           00
#
#   c08_008_wa16p_pp_ptrn_scr_trly c08_007_wa16p_pp_ptrn_bus_trly  \
# 0                             00                             06
# 1                             00                             00
# 2                             00                             00
# 3                             00                             00
# 4                             00                             00
# 5                             00                             01
# 6                             00                             17
# 7                             00                             16
# 8                             00                             08
# ...
# 6                             33                 40            79
# 7                             21                 28            80
# 8                             68                 87            95
# 9                             83                 92            99
#
#   c25_122_soohu_mdn_re_tax c25_121_soohu_mdn_hoc_womortg  \
# 0                    01307                         00420
# 1                    02718                         00543
# 2                    01341                         00425
# 3                    02633                         00454
# 4                    00795                         00551
# 5                    10001                         00980
# 6                    00599                         00371
# 7                    03159                         00649
# 8                    02521                         00502
# 9                    02635                         00469
#
#   c25_120_soohu_mdn_hoc_wmortg c25_119_soohu_pct_sec_mrtg_hel  \
# 0                        01278                             17
# 1                        01605                             22
# 2                        01383                             06
# 3                        01138                             21
# 4                        01235                             15
# 5                        03450                             27
# 6                        00869                             00
# 7                        03556                             00
# 8                        01856                             14
# 9                        02207                             16
#
#   c25_118_soohu_pct_mrtg c25_117_soohupv_1_miln_plus  \
# 0                     77                          02
# 1                     91                          00
# 2                     70                          00
# 3                     71                          00
# 4                     47                          00
# 5                     88                          00
# 6                     19                          00
# 7                     35                          00
# 8                     67                          02
# 9                     94                          00
#
#   c25_116_soohupv_500000_plus c25_115_soohupv_200000_plus  \
# 0                          02                          21
# 1                          03                          57
# 2                          01                          28
# 3                          00                          02
# 4                          02                          16
# 5                          44                          92
# 6                          00                          00
# 7                          72                          99
# 8                          04                          90
# 9                          27                          97
#
#   c25_114_soohupv_150000_plus c25_113_soohupv_100000_plus  \
# 0                          40                          62
# 1                          69                          78
# 2                          60                          93
# 3                          39                          77
# 4                          39                          65
# 5                          93                          93
# 6                          34                          48
# 7                          99                          99
# 8                          92                          98
# 9                          98                          98
#
#   c25_112_soohupv_80000_plus c25_111_soohupv_50000_plus  \
# 0                         71                         90
# 1                         83                         96
# 2                         94                         96
# 3                         95                         95
# 4                         78                         88
# 5                         93                         97
# 6                         48                         90
# 7                         99                         99
# 8                         98                         98
# 9                         98                         99
#
#   c25_110_soohupv_750000_999999 c25_109_soohupv_500000_749999  \
# 0                            00                            00
# 1                            00                            03
# 2                            00                            01
# 3                            00                            00
# 4                            00                            02
# 5                            01                            43
# 6                            00                            00
# 7                            12                            60
# 8                            00                            02
# 9                            00                            27
#
#   c25_108_soohupv_400000_499999 c25_107_soohupv_300000_399999  \
# 0                            00                            01
# 1                            05                            16
# 2                            01                            09
# 3                            00                            00
# 4                            01                            00
# 5                            26                            14
# 6                            00                            00
# 7                            16                            00
# 8                            11                            56
# 9                            39                            19
#
#   c25_106_soohupv_250000_299999 c25_105_soohupv_200000_249999  \
# 0                            07                            11
# 1                            17                            16
# 2                            07                            10
# 3                            00                            02
# 4                            01                            12
# 5                            05                            03
# 6                            00                            00
# 7                            12                            00
# 8                            13                            06
# 9                            08                            04
#
#   c25_104_soohupv_175000_199999 c25_103_soohupv_150000_174999  \
# 0                            08                            11
# 1                            03                            09
# 2                            18                            14
# 3                            07                            30
# 4                            07                            16
# 5                            01                            00
# 6                            00                            34
# 7                            00                            00
# 8                            02                            00
# 9                            01                            00
#
#   c25_102_soohupv_125000_149999 c25_101_soohupv_100000_124999  \
# 0                            13                            09
# 1                            01                            08
# 2                            19                            14
# 3                            25                            13
# 4                            08                            18
# 5                            00                            00
# 6                            00                            14
# 7                            00                            00
# 8                            02                            04
# 9                            00                            00
#
#   c25_100_soohupv_50000_99999 c25_099_soohupv_25000_49999  \
# 0                          28                          05
# 1                          18                          00
# 2                          03                          00
# 3                          18                          03
# 4                          23                          08
# 5                          04                          00
# 6                          42                          00
# 7                          00                          00
# 8                          00                          02
# 9                          01                          01
#
#   c25_098_soohupv_lt_25000 c25_097_oohu_mdn_val c25_096_oohu_avg_val  \
# 0                       05                01312                01594
# 1                       04                02213                02156
# 2                       04                01674                01778
# 3                       02                01392                01309
# 4                       04                01210                01319
# 5                       03                04786                04281
# 6                       10                00767                00975
# 7                       00                05903                05601
# 8                       00                03378                03659
# 9                       00                04421                04024
#
#   c25_095_rohugmrp_2000_plus c25_094_rohugmrp_500_plus  \
# 0                         00                        94
# 1                         00                        99
# 2                         00                        89
# 3                         00                        99
# 4                         16                        99
# 5                         00                        99
# 6                         00                        65
# 7                         07                        87
# 8                         31                        99
# 9                         74                        99
#
#   c25_093_rohugmrp_300_plus c25_092_rohugmrp_200_plus  \
# 0                        99                        99
# 1                        99                        99
# 2                        96                        96
# 3                        99                        99
# 4                        99                        99
# 5                        99                        99
# 6                        99                        99
# 7                        87                        91
# 8                        99                        99
# 9                        99                        99
#
#   c25_091_rohugmrp_1500_1999 c25_090_rohugmrp_1250_1499  \
# 0                         01                         04
# 1                         17                         00
# 2                         18                         23
# 3                         00                         40
# 4                         00                         09
# 5                         99                         00
# 6                         00                         21
# 7                         21                         27
# 8                         00                         00
# 9                         26                         00
#
#   c25_089_rohugmrp_1000_1249 c25_088_rohugmrp_750_999  \
# 0                         22                       35
# 1                         18                       09
# 2                         24                       07
# 3                         46                       00
# 4                         13                       50
# 5                         00                       00
# 6                         00                       05
# 7                         29                       03
# 8                         00                       69
# 9                         00                       00
#
#   c25_087_rohugmrp_500_749 c25_086_rohugmrp_400_499 c25_085_rohugmrp_300_399  \
# 0                       32                       05                       00
# 1                       56                       00                       00
# 2                       17                       07                       00
# 3                       14                       00                       00
# 4                       12                       00                       00
# 5                       00                       00                       00
# 6                       39                       26                       09
# 7                       00                       00                       00
# 8                       00                       00                       00
# 9                       00                       00                       00
#
#   c25_084_rohugmrp_200_299 c25_083_rohugmrp_100_199 c25_082_rohugmrp_lt_100  \
# 0                       00                       00                      01
# 1                       00                       00                      00
# 2                       00                       00                      04
# 3                       00                       00                      00
# 4                       00                       00                      00
# 5                       00                       00                      00
# 6                       00                       00                      00
# 7                       04                       00                      09
# 8                       00                       00                      00
# 9                       00                       00                      00
#
#   c25_081_rohu_mdn_grs_rent c25_080_rohu_avg_grs_rent  \
# 0                     00840                     00857
# 1                     00594                     00928
# 2                     01169                     01137
# 3                     01196                     01095
# 4                     00950                     01108
# 5                     01750                     00000
# 6                     00648                     00757
# 7                     01326                     01317
# 8                     00972                     00000
# 9                     02558                     02433
#
#   c25_079_hup_cmplt_ktn_fclty c25_078_hup_cmplt_plmb_fclty c25_077_hup_tel  \
# 0                          97                           99              96
# 1                          99                           93              95
# 2                          99                           99              97
# 3                          96                           96              99
# 4                          97                           99              97
# 5                          97                           97              99
# 6                          86                           99              98
# 7                          99                           99              88
# 8                          92                           99              99
# 9                          99                           99              99
#
#   c25_076_hup_5p_brm c25_075_hup_4_brm c25_074_hup_3_brm indiv_enterprise_id
# 0                 02                12                37            12021357
# 1                 00                40                32            16613323
# 2                 01                33                45            19877687
# 3                 01                07                82            23932373
# 4                 02                15                43            24711473
# 5                 11                60                19            17253124
# 6                 00                10                43            26063331
# 7                 00                00                14            17255615
# 8                 10                51                23            30644622
# 9                 45                40                13            22133038

# %%
#: cencus first, "c" initial words.

colname_select_part_char = ",".join( census_topvars_lt ) # for census
#origids_char = ",".join( m31pop_100k.origId.map(str) ) # already uploaded to database as a table much faster.

# %%
# sel = '''
# select top 100 distinct indiv_enterprise_id, {0} from rawdata.census
# where indiv_enterprise_id in ({1});
# '''.format(colname_select_part_char, origids_char)

# census_tables = pd.read_sql(sel, con)
# census_tables.head(10)

# %%
sel = '''
select distinct m.indiv_enterprise_id, {0} from rawdata.census as c
right join analyst.oncology_m4_8_6 as m on c.indiv_enterprise_id = m.indiv_enterprise_id
order by indiv_enterprise_id;
'''.format(colname_select_part_char)

census_tables = pd.read_sql(sel, con)
census_tables.head(10)
# Out:
#   indiv_enterprise_id c24_004_ocp_manufacturing_pp  \
# 0            10044079                           06
# 1            10049553                           06
# 2            10049744                           06
# 3            10051016                           11
# 4               10074                           03
# 5             1007869                           05
# 6            10089743                           19
# 7            10152833                           04
# 8            10166078                           09
# 9            10169064                           08
#
#   c08_001_wa16p_pp_wrk_in_cnty c23_006_empd_fa16p_pp c25_064_ohph_electricity  \
# 0                           37                    55                       30
# 1                           77                    53                       74
# 2                           49                    72                       18
# 3                           55                    54                       04
# 4                           92                    49                       10
# 5                           61                    50                       96
# 6                           89                    50                       39
# 7                           88                    58                       96
# 8                           97                    57                       88
# 9                           56                    68                       27
#
#   c27_010_hi_pp_no_hi c05_001_ctltpp_ntv_citzn c19_043_hhip_ss  \
# 0                  14                       89              45
# 1                  38                       58              21
# 2                  07                       88              12
# 3                  16                       72              28
# 4                  04                       81              45
# 5                  17                       90              34
# 6                  29                       68              38
# 7                  21                       74              24
# 8                  18                       29              31
# 9                  03                       92              10
#
#   c01_018_hspo_a65p_tlpp c08_019_wa16p_cmtm_mdn c11_035_hhr_pct_hsp  \
# 0                     06                    029                  27
# 1                     03                    024                  28
# 2                     03                    032                  20
# 3                     05                    031                  08
# 4                     02                    020                  22
# 5                     11                    032                  26
# 6                     03                    030                  05
# 7                     14                    029                  46
# 8                     14                    035                  93
# 9                     02                    029                  07
#
#   c08_029_hhvap_2_veh c27_001_hi_pp c04_015_atltpp_italian  \
# 0                  69            86                     01
# 1                  34            62                     00
# 2                  66            93                     02
# 3                  49            84                     06
# 4                  25            96                     18
# 5                  38            83                     08
# 6                  43            71                     01
# 7                  54            79                     03
# 8                  46            82                     01
# 9                  51            97                     07
#
#   c08_004_wa16p_pp_drv_alone c08_002_wa16p_pp_wrk_out_cnty  \
# 0                         92                            63
# 1                         68                            23
# 2                         81                            51
# 3                         62                            30
# 4                         73                            08
# 5                         80                            38
# 6                         80                            06
# 7                         76                            11
# 8                         86                            03
# 9                         85                            43
#
#   c04_011_atltpp_german c04_001_atltpp_american c23_005_empd_ma16p_pp  \
# 0                    08                      02                    73
# 1                    02                      03                    79
# 2                    18                      15                    78
# 3                    03                      08                    66
# 4                    12                      07                    66
# 5                    09                      17                    59
# 6                    08                      04                    76
# 7                    13                      04                    68
# 8                    00                      03                    68
# 9                    23                      11                    82
#
#   c06_002_pobtpp_res_oos_born c23_004_empd_a16p_pp c04_007_atltpp_english  \
# 0                          29                   63                     10
# 1                          18                   65                     02
# 2                          41                   75                     09
# 3                          14                   60                     01
# 4                          16                   57                     08
# 5                          48                   54                     06
# 6                          12                   64                     09
# 7                          32                   62                     03
# 8                          07                   62                     00
# 9                          48                   75                     12
#
#   c16_002_lah_pp_spnsh c04_030_atltpp_othr c27_003_hi_pp_emplr_provd_prvt  \
# 0                   31                  62                             62
# 1                   34                  74                             23
# 2                   11                  38                             74
# 3                   10                  50                             51
# 4                   06                  28                             74
# 5                   26                  33                             46
# 6                   03                  54                             44
# 7                   47                  66                             50
# 8                   94                  92                             41
# 9                   06                  35                             75
#
#   c03_002_hspogn_tpp_non_hsp c25_096_oohu_avg_val  \
# 0                         61                01299
# 1                         64                02128
# 2                         76                02426
# 3                         89                04087
# 4                         86                04099
# 5                         71                01416
# 6                         95                01664
# 7                         50                01742
# 8                         09                01680
# 9                         91                04035
#
#   c03_006_hspogn_tltpp_othr_hspo c23_002_lf_ma16p_pp c23_003_lf_fa16p_pp  \
# 0                             02                  75                  61
# 1                             12                  83                  56
# 2                             08                  81                  73
# 3                             19                  73                  60
# 4                             08                  69                  53
# 5                             07                  62                  52
# 6                             17                  89                  55
# 7                             09                  74                  63
# 8                             31                  71                  61
# 9                             02                  85                  69
#
#   c24_010_ocp_fins_re_rntl_lsgpp c11_024_hhr_pct_age_65_74  \
# 0                             02                        29
# 1                             06                        12
# 2                             13                        04
# 3                             12                        22
# 4                             03                        20
# 5                             02                        14
# 6                             19                        14
# 7                             09                        10
# 8                             10                        11
# 9                             14                        04
#
#   c24_033_ocp_self_empd_pp c06_001_pobtpp_res_in_ste_born  \
# 0                       04                             58
# 1                       14                             38
# 2                       09                             43
# 3                       08                             54
# 4                       05                             65
# 5                       09                             32
# 6                       02                             54
# 7                       14                             25
# 8                       08                             21
# 9                       07                             41
#
#   c11_036_hhr_pct_nhsp c25_062_ohph_utlty_gas c25_118_soohu_pct_mrtg  \
# 0                   73                     70                     69
# 1                   72                     25                     71
# 2                   80                     79                     93
# 3                   92                     90                     83
# 4                   78                     49                     65
# 5                   74                     01                     76
# 6                   95                     53                     20
# 7                   54                     00                     78
# 8                   07                     02                     62
# 9                   93                     72                     91
#
#   c24_032_ocp_pfp_nself_empd_pp c25_074_hup_3_brm c03_001_hspogn_tpp_hsp  \
# 0                            71                55                     39
# 1                            84                16                     36
# 2                            73                60                     24
# 3                            76                14                     11
# 4                            49                33                     14
# 5                            76                56                     29
# 6                            85                68                     05
# 7                            74                47                     50
# 8                            73                27                     91
# 9                            75                17                     09
#
#   c08_025_wa16p_pp_cmtm_60p_mn c06_004_pobtpp_forgn_born  \
# 0                           05                        11
# 1                           08                        42
# 2                           07                        12
# 3                           26                        28
# 4                           09                        19
# 5                           11                        10
# 6                           08                        32
# 7                           09                        26
# 8                           17                        71
# 9                           06                        08
#
#   c16_001_lah_pp_english_only c08_020_wa16p_pp_cmtm_1_29_mn  \
# 0                          67                            52
# 1                          45                            57
# 2                          85                            36
# 3                          64                            48
# 4                          88                            74
# 5                          72                            43
# 6                          90                            50
# 7                          43                            52
# 8                          05                            28
# 9                          86                            53
#
#   c15_007_ea_pp_atand_bd
# 0                     19
# 1                     18
# 2                     20
# 3                     23
# 4                     20
# 5                     15
# 6                     29
# 7                     15
# 8                     13
# 9                     27

# %%
census_tables.shape
# Out:
# (3982, 45)

# %%
# Out:
# <bound method Series.duplicated of 0         10001245
# 1         10001352
# 2         10002740
# 3         10002888
# 4         10005671
# 5         10005718
# 6         10006975
# 7         10009101
# 8         10009491
# 9         10009721
# 10        10009739
# 11         1000976
# 12        10009961
# 13        10011901
# 14        10012018
# 15        10013512
# 16        10013657
# 17        10013728
# 18        10014500
# 19        10015965
# 20        10016436
# 21        10016995
# 22         1001729
# 23        10019202
# 24        10020238
# 25        10020476
# 26        10022735
# 27          100238
# 28        10025783
# 29        10025897
# 30        10025917
# 31        10027358
# 32        10029945
# 33        10033234
# 34        10033271
# 35        10037011
# 36        10037566
# 37        10039214
# 38        10039281
# 39        10042097
# 40        10045732
# 41        10046408
# 42        10047039
# 43         1004797
# 44        10048042
# 45         1004890
# 46        10048974
# 47        10050496
# 48        10050549
# 49        10051891
# 50        10053116
# 51        10053628
# 52        10055279
# 53        10056133
# 54         1005634
# 55        10058265
# 56        10059569
# 57         1005970
# 58        10059887
# 59         1006074
# 60        10061421
# 61         1006242
# 62        10063251
# 63        10065466
# 64        10067342
# 65        10067641
# 66        10067905
# 67        10068397
# 68        10072912
# 69           10074
# 70        10076147
# 71        10077508
# 72        10078092
# 73        10079110
# 74        10079440
# 75         1008031
# 76        10080460
# 77        10080834
# 78         1008276
# 79        10086582
#             ...
# 100603    99922757
# 100604    99923022
# 100605    99923532
# 100606    99923580
# 100607    99923664
# 100608    99925060
# 100609     9992653
# 100610    99928456
# 100611    99929163
# 100612     9993020
# 100613    99930854
# 100614     9993342
# 100615    99933506
# 100616    99934833
# 100617     9993489
# 100618    99935582
# 100619     9993852
# 100620    99938972
# 100621    99939168
# 100622    99942397
# 100623    99943895
# 100624    99944081
# 100625    99945525
# 100626    99945828
# 100627    99949995
# 100628    99950153
# 100629     9995105
# 100630     9995165
# 100631    99952547
# 100632    99953779
# 100633    99954006
# 100634    99956481
# 100635     9995801
# 100636    99958773
# 100637    99959284
# 100638    99959323
# 100639    99959922
# 100640    99960006
# 100641    99961662
# 100642    99962306
# 100643    99962706
# 100644    99963761
# 100645    99964021
# 100646    99965948
# 100647    99966269
# 100648     9996638
# 100649    99966431
# 100650    99968327
# 100651    99968646
# 100652    99970434
# 100653    99971061
# 100654    99971844
# 100655    99971996
# 100656    99972517
# 100657    99975872
# 100658     9997600
# 100659    99979235
# 100660    99979953
# 100661    99981182
# 100662    99981720
# 100663      999819
# 100664    99981949
# 100665    99982529
# 100666     9998300
# 100667    99983295
# 100668     9998398
# 100669     9998401
# 100670     9998460
# 100671    99987255
# 100672    99989200
# 100673    99991044
# 100674    99991498
# 100675    99991701
# 100676    99991784
# 100677     9999277
# 100678    99993069
# 100679    99994565
# 100680    99995373
# 100681    99997146
# 100682    99999236
# Name: indiv_enterprise_id, Length: 100683, dtype: object>

# %%
#: then lfstl_assmt, "v" initial words.

colname_select_part_char = ",".join( lifestyle_topvars_lt ) # for lfstl_assmt
#origids_char = ",".join( m31pop_100k.origId.map(str) )


sel = '''
select distinct m.indiv_enterprise_id, {0} from rawdata.lfstl_assmt as l
right join analyst.oncology_m4_8_6 as m on l.indiv_enterprise_id = m.indiv_enterprise_id
order by indiv_enterprise_id;
'''.format(colname_select_part_char)

lfstl_tables = pd.read_sql(sel, con)
lfstl_tables.head(10)
# Out:
#   indiv_enterprise_id v3589_mcu_primtm_tv v4000_consmr_promnc_ind  \
# 0            10044079                  03                      09
# 1            10049553                  07                      02
# 2            10049744                  05                      10
# 3            10051016                  05                      01
# 4               10074                  05                      10
# 5             1007869                  06                      01
# 6            10089743                  04                      10
# 7            10152833                  05                      06
# 8            10166078                  05                      10
# 9            10169064                  08                      07
#
#   v8655_lfestg_cd v8671_incm_estd_hh_narw_rng v3102_cntry_of_orgn_high_dtl  \
# 0             345                           A                           4G
# 1            None                           D                           30
# 2             335                           8                           4G
# 3             141                           D                           4Z
# 4             215                           B                           4G
# 5            None                        None                           4J
# 6             262                           7                           4G
# 7            None                           1                           30
# 8             355                           B                           30
# 9             355                           C                           40
#
#   v8201_incm_estd_hh_highr_rng v8617_a2yrincr_2nd_indiv v8637_occup_ip_indiv  \
# 0                            E                       62                    1
# 1                            J                     None                 None
# 2                            D                       56                    7
# 3                            I                       54                 None
# 4                            F                     None                    1
# 5                         None                       50                 None
# 6                            D                     None                    1
# 7                            1                     None                 None
# 8                            F                       54                    4
# 9                            F                       44                 None
#
#   v7616_1_a2yrincr_1_indv_cd v8626_a2yrincr_ip_indiv v8616_a2yrincr_1st_indiv  \
# 0                         62                      62                       62
# 1                         46                      64                     None
# 2                         56                      54                       56
# 3                         26                      18                       26
# 4                         44                      44                       44
# 5                         54                      50                       54
# 6                         48                      48                       48
# 7                         44                      44                       44
# 8                         64                      54                       64
# 9                         60                      44                       60
#
#   v8610_2_fng_1st_indiv_mid_init v8640_num_of_src v2778_brnd_nm_med_ppns  \
# 0                              Y               40                     07
# 1                           None               40                     04
# 2                              G               46                     06
# 3                              L               41                     08
# 4                              U               40                     10
# 5                              Y               39                     08
# 6                              W               38                     09
# 7                           None               44                     06
# 8                           None               39                     04
# 9                              P               34                     07
#
#   v8642_hmv_estd v8644_home_purchs_yr_yyyy
# 0              G                      2012
# 1              N                      None
# 2              M                      2001
# 3              Q                      1995
# 4              Q                      2003
# 5              H                      2017
# 6              J                      2007
# 7              G                      None
# 8              I                      2004
# 9              Q                      2008

# %%
lfstl_tables.shape
# Out:
# (3982, 17)

# %% [markdown]
# ## output feather two lists.

# %%
census_tables.to_feather("/gnshealthcare/shared/yyang/data/ses_data/census_tables_oncology_m4_8_6.feather")

# %%
lfstl_tables.to_feather("/gnshealthcare/shared/yyang/data/ses_data/lfstl_tables_oncology_m4_8_6.feather")

# %%
# import feather
# # feather.write_dataframe(frames,dest="/gnshealthcare/shared/yyang/data/ses_data/frames_ses_forTop100kSamples.feather")
# frames_df.to_feather(fname="/gnshealthcare/shared/yyang/data/ses_data/frames_allSes__forTop100kSamples.feather")

# %% [markdown]
# ##### Summary: now R can read feather binary output and continue the analysis.

# %%
os.makedirs("/gnshealthcare/shared/yyang/data/ses_data", exist_ok=True, mode=0o755 )

# %%
os.chdir("/gnshealthcare/shared/yyang/data/ses_data")

# %%
#os.chdir("/gnshealthcare/shared/nli/dataframe/r36m/")

# %%
print(os.getcwd())

# %%
os.listdir()

# %%
new_path = os.path.join('/gnshealthcare/shared/yyang/', 'Models', 'SES_models')
os.makedirs(new_path, mode=0o755, exist_ok=True)
